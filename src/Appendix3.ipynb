# %%
import json
from misc import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %%
def plot_performance(d, title, wv=True, legend=True):
    h = [
        Patch(color="blue", label="Training set"),
        Patch(color="green", label="Test set"),
        Patch(color="red", label="Perfect prediction"),
    ]
    if wv:
        h.append(Patch(color="purple", label="Augmented pseudoexamples"))
        plt.scatter(d["train.aug.reals"], d["train.aug.preds"], color="purple")
    plt.plot(d["train.aug.reals"], d["train.aug.reals"], color="red")
    plt.scatter(d["test.reals"], d["test.preds"], color="green")
    plt.scatter(d["train.reals"], d["train.preds"], color="blue")
    plt.xlim((0,1))
    plt.ylim((0,1))
    plt.xlabel("Real AUROCs")
    plt.ylabel("Predicted AUROCs")
    if legend:
        plt.legend(
            loc="best",
            handles=h
        )
    plt.title(title)

# %%
with open("../results/en_study.pkl_wv.json", "r") as oh:
    english_results_wv = json.load(oh)
with open("../results/en_study.pkl_1hot.json", "r") as oh:
    english_results_1hot = json.load(oh)
with open("../results/ru_study.pkl_wv.json", "r") as oh:
    russian_results_wv = json.load(oh)
with open("../results/ru_study.pkl_1hot.json", "r") as oh:
    russian_results_1hot = json.load(oh)
with open("../results/joint_wv.json", "r") as oh:
    joint_results = json.load(oh)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20, 20
rcParams['font.size'] = 16

# %%
tbl = {
    "trial": [
        "Both", "English wv", "English 1hot", 
        "Russian wv", "Russian wv"
    ],
    "train SCC": [
        joint_results["train.SCC"][0], english_results_wv["train.SCC"][0],
        english_results_1hot["train.SCC"][0], russian_results_wv["train.SCC"][0],
        russian_results_1hot["train.SCC"][0]
    ],
    "train SCC p-value": [
        joint_results["train.SCC"][1], english_results_wv["train.SCC"][1],
        english_results_1hot["train.SCC"][1], russian_results_wv["train.SCC"][1],
        russian_results_1hot["train.SCC"][1]
    ],
    "test SCC": [
        joint_results["test.SCC"][0], english_results_wv["test.SCC"][0],
        english_results_1hot["test.SCC"][0], russian_results_wv["test.SCC"][0],
        russian_results_1hot["test.SCC"][0]
    ],
    "test SCC p-value": [
        joint_results["test.SCC"][1], english_results_wv["test.SCC"][1],
        english_results_1hot["test.SCC"][1], russian_results_wv["test.SCC"][1],
        russian_results_1hot["test.SCC"][1]
    ],
}
tbl = pd.DataFrame(tbl)

# %%
tbl
# Out:
#           trial  train SCC  train SCC p-value  test SCC  test SCC p-value
# 0          Both   0.999993       0.000000e+00 -0.051836          0.614086
# 1    English wv   0.986756      4.820288e-152  0.132861          0.362792
# 2  English 1hot   0.996812      1.362049e-210  0.016685          0.909404
# 3    Russian wv   0.968505      1.125381e-116  0.079027          0.593396
# 4    Russian wv   0.976394      2.073982e-128  0.179286          0.217718

# %%
print(tbl.to_latex())
# Out:
# \begin{tabular}{llrrrr}
# \toprule
# {} &         trial &  train SCC &  train SCC p-value &  test SCC &  test SCC p-value \\
# \midrule
# 0 &          Both &   0.999993 &       0.000000e+00 & -0.051836 &          0.614086 \\
# 1 &    English wv &   0.986756 &      4.820288e-152 &  0.132861 &          0.362792 \\
# 2 &  English 1hot &   0.996812 &      1.362049e-210 &  0.016685 &          0.909404 \\
# 3 &    Russian wv &   0.968505 &      1.125381e-116 &  0.079027 &          0.593396 \\
# 4 &    Russian wv &   0.976394 &      2.073982e-128 &  0.179286 &          0.217718 \\
# \bottomrule
# \end{tabular}

# %%
fig = plt.figure(constrained_layout=True)
gs = fig.add_gridspec(2, 6)
en_ohot = fig.add_subplot(gs[0,0:3])
plot_performance(
    english_results_1hot, "A. One-hot Model for English", False, False
)
ru_ohot = fig.add_subplot(gs[0,3:])
plot_performance(
    russian_results_1hot, "B.  One-hot Model for Russian", False
)
joint_wv = fig.add_subplot(gs[1,0:2])
plot_performance(
    joint_results, "C.  Word Vector Model for Both", True, False
)
en_wv = fig.add_subplot(gs[1,2:4])
plot_performance(
    english_results_wv, "D. Word Vector Model for English", True, False
)
ru_wv = fig.add_subplot(gs[1,4:])
plot_performance(
    russian_results_wv, "E. Word Vector Model for Russian", True
)
